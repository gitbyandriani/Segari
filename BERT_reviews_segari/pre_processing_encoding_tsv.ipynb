# %% [markdown]
# #Import data

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("/content/drive/MyDrive/segari_data_not_clean.tsv", sep='\t')

data.head()
# Out:
#    score                                            content  category
# 0      5                                         Mantabbbbb  positive
# 1      2  Semenjak cod ditiadakan yg ke wilayahku udah g...  negative
# 2      5  Sayang bgt ya buat si kecil kurang lengkap klo...  positive
# 3      5  Belum pernah belanja, tapi liatt teman selalu ...  positive
# 4      5  sayuran fresh,bersih & semua barang kualitas baik  positive

# %% [markdown]
# #Case Folding

# %%
# Case Folding
data['content'] = data['content'].str.lower()

print('Case Folding Result : \n')
print(data['content'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0                                           mantabbbbb
# 1    semenjak cod ditiadakan yg ke wilayahku udah g...
# 2    sayang bgt ya buat si kecil kurang lengkap klo...
# 3    belum pernah belanja, tapi liatt teman selalu ...
# 4    sayuran fresh,bersih & semua barang kualitas baik
# Name: content, dtype: object

# %% [markdown]
# #Tokenize

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import string
import re #regex library

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# ------ Tokenizing ---------

def remove_content_special(text):
    # remove tab, new line, and backslash
    text = text.replace('\\t', ' ').replace('\\n', ' ').replace('\\u', '').replace('\\', '')

    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')

    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", " ", text).split())

    # remove incomplete URL
    text = text.replace("http://", " ").replace("https://", " ")

    return text

data['content'] = data['content'].apply(remove_content_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

data['content'] = data['content'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

data['content'] = data['content'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

data['content'] = data['content'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

data['content'] = data['content'].apply(remove_whitespace_multiple)

# remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

data['content'] = data['content'].apply(remove_single_char)

# NLTK word_tokenize
def word_tokenize_wrapper(text):
    return word_tokenize(text)

data['content_tokens'] = data['content'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n')
print(data['content_tokens'].head())
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# 0                                         [mantabbbbb]
# 1    [semenjak, cod, ditiadakan, yg, ke, wilayahku,...
# 2    [sayang, bgt, ya, buat, si, kecil, kurang, len...
# 3    [belum, pernah, belanja, tapi, liatt, teman, s...
# 4    [sayuran, freshbersih, semua, barang, kualitas...
# Name: content_tokens, dtype: object

# %% [markdown]
# #Stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo',
                       'kalo', 'amp', 'biar', 'bikin', 'bilang',
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih',
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya',
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't',
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])

# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_csv("stopwords.txt", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# ---------------------------------------------------------------------------------------

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

data['content_tokens_stw'] = data['content_tokens'].apply(stopwords_removal)


print(data['content_tokens_stw'].head())
# Out:
# 0                                         [mantabbbbb]
# 1    [semenjak, cod, ditiadakan, wilayahku, udah, p...
# 2    [sayang, bgt, lengkap, lengkap, skalian, kn, b...
# 3    [belanja, liatt, teman, belanja, lewatt, aplik...
# 4             [sayuran, freshbersih, barang, kualitas]
# Name: content_tokens_stw, dtype: object

# %% [markdown]
# #Normalisasi

# %%
normalizad_word = pd.read_csv("normalisasi2.csv", encoding='ISO-8859-1')

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1]

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

data['content_normalized'] = data['content_tokens_stw'].apply(normalized_term)

data['content_normalized'].head(10)
# Out:
# 0                                             [mantap]
# 1    [semenjak, cod, ditiadakan, wilayahku, sudah, ...
# 2    [sayang, banget, lengkap, lengkap, sekalian, k...
# 3    [belanja, lihat, teman, belanja, lewat, aplika...
# 4             [sayuran, freshbersih, barang, kualitas]
# 5    [kualitas, barang, fresh, segar, bersih, pengi...
# 6    [sekarang, belanja, yang, komplain, mengaco, c...
# 7             [produk, bagus, packaging, safe, banget]
# 8                     [pengiriman, cepatbarang, bagus]
# 9                              [bagus, cepat, praktis]
# Name: content_normalized, dtype: object

# %% [markdown]
# #Stemming

# %%
# !pip install swifter
# Out:
# Requirement already satisfied: swifter in /usr/local/lib/python3.10/dist-packages (1.4.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (1.5.3)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.10/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2023.8.0)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (4.66.1)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (8.1.6)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (23.1)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (1.23.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask[dataframe]>=2.10.0->swifter) (3.16.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->swifter) (1.16.0)

# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in data['content_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '

print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])

print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

data['content_tokens_stemmed'] = data['content_normalized'].swifter.apply(get_stemmed_term)
print(data['content_tokens_stemmed'])
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# mengaco : aco
# transfer : transfer
# nugelo : nugelo
# segari : segar
# produk : produk
# bagus : bagus
# packaging : packaging
# safe : safe
# cepatbarang : cepatbarang
# praktis : praktis
# beberapa : beberapa
# kali : kali
# kosong : kosong
# display : display
# lahbaik : lahbaik
# promo : promo
# ada : ada
# uang : uang
# coin : coin
# begitu : begitu
# biaya : biaya
# penanganan : tangan
# gabung : gabung
# mending : mending
# pindah : pindah
# toko : toko
# sebelah : belah
# keren : keren
# membantu : bantu
# emak : emak
# dari : dari
# tukang : tukang
# sayur : sayur
# tempatku : tempat
# min : min
# sampai : sampai
# sayurnya : sayur
# promonya : promonya
# very : very
# worth : worth
# itu : itu
# anak : anak
# riweh : riweh
# pesan : pesan
# hp : hp
# langsung : langsung
# buah : buah
# buahan : buah
# juga : juga
# harga : harga
# ok : ok
# sesuai : sesuai
# jadwal : jadwal
# pengemasan : emas
# telur : telur
# ditingkatkan : tingkat
# pengamanan : aman
# ditindih : tindih
# good : good
# aplication : aplication
# kebanyakan : banyak
# refund : refund
# saran : saran
# mengadakan : ada
# kuantitas : kuantitas
# tutup : tutup
# layanan : layan
# jam : jam
# telat : telat
# menit : menit
# okelah : oke
# kurir : kurir
# dihubungi : hubung
# angkat : angkat
# hubungi : hubung
# cs : cs
# maaf : maaf
# tanggung : tanggung
# kompensasi : kompensasi
# apalah : apa
# aplikasi : aplikasi
# sayangnya : sayang
# pemesanan : mesan
# enggak bisa : enggak bisa
# bayar : bayar
# golden : golden
# mom : mom
# sehari : hari
# bngetpelayanan : bngetpelayanan
# pengantar : antar
# mantul : mantul
# utama : utama
# dapat : dapat
# besaran : besar
# disegari : gari
# respon : respon
# pelayanan : layan
# lama : lama
# bagusloading : bagusloading
# lamamungkin : lamamungkin
# server : server
# the : the
# worst : worst
# pengalaman : alam
# daging : daging
# giling : giling
# packing : packing
# rapi : rapi
# dus : dus
# tapi : tapi
# beku : beku
# terima : terima
# kasih : kasih
# puas : puas
# menarik : tarik
# rekomendasi : rekomendasi
# kosan : kosan
# pasar : pasar
# pedagang : dagang
# bahan : bahan
# bahannya : bahan
# sukakk : sukakk
# semoga : moga
# bisa : bisa
# miring : miring
# maklum : maklum
# mak : mak
# zaman : zaman
# wajib : wajib
# efisiensi : efisiensi
# kebutuhan : butuh
# masak : masak
# mudah : mudah
# buahnya : buah
# mengirim : kirim
# mageran : mageran
# alhamdulillah : alhamdulillah
# repot : repot
# kepasar : pasar
# terjangkau : jangkau
# kemarin : kemarin
# diskon : diskon
# free : free
# ongkir : ongkir
# sukses : sukses
# suka : suka
# pengirimannya : kirim
# ramah : ramah
# customer : customer
# bantuan : bantu
# care : care
# melayani : layan
# kak : kak
# jangkauan : jangkau
# terbatas : batas
# bersaing : saing
# aplikasinya : aplikasi
# bagustapi : bagustapi
# bintang : bintang
# ajadi : ajadi
# lokasiku : lokasi
# bisatolong : bisatolong
# kirim : kirim
# buruk : buruk
# manggis : manggis
# busuk : busuk
# keras : keras
# diganti : ganti
# belanjaannya : belanja
# dana : dana
# konfirmasi : konfirmasi
# pemberitahuan : pemberitahuan
# menunggu : tunggu
# info : info
# kembalikan : kembali
# gua : gua
# heiiii : heiiii
# buru : buru
# kembaliinnya : kembaliinnya
# batalkan : batal
# sekalinya : sekali
# batalin : batalin
# suruh : suruh
# kerja : kerja
# dzolim : dzolim
# berguna : guna
# memuaskan : muas
# segarkiriman : segarkiriman
# driver : driver
# service : service
# parah : parah
# kapok : kapok
# pilih : pilih
# turbo : turbo
# pesanan : pesan
# proses : proses
# status : status
# berubah : ubah
# pembatalan : batal
# susah : susah
# ditambah : tambah
# total : total
# kesalahan : salah
# dilempar : lempar
# operasional : operasional
# bank : bank
# pahadal : pahadal
# selasa : selasa
# rabu : rabu
# kamis : kamis
# jumat : jumat
# besok : besok
# weekend : weekend
# senin : senin
# gila : gila
# chat : chat
# balas : balas
# mesin : mesin
# ulang : ulang
# kelar : kelar
# pokok : pokok
# mah : mah
# waktu : waktu
# sampainya : sampai
# ojeknya : ojek
# boskuhh : boskuhh
# layan : layan
# benar : benar
# level : level
# belum : belum
# diproses : proses
# baru : baru
# kalah : kalah
# box : box
# astro : astro
# komit : komit
# janjikan : janji
# menamai : nama
# memakai : pakai
# memang : memang
# butuh : butuh
# bermanfaat : manfaat
# belanjanya : belanja
# memenuhi : penuh
# hidup : hidup
# seharihari : seharihari
# ikan : ikan
# belut : belut
# sama : sama
# sidat : sidat
# sehrus : sehrus
# hehhe : hehhe
# kec : kec
# parung : parung
# waru : waru
# jaya : jaya
# pengantaran : antar
# on : on
# time : time
# produknya : produk
# never : never
# failed : failed
# sayurannya : sayur
# pertamakali : pertamakali
# dikirim : kirim
# terimakasih : terimakasih
# super : super
# duper : duper
# kilat : kilat
# order : order
# ngalamin : ngalamin
# estimasi : estimasi
# bagaimana : bagaimana
# orang : orang
# dtng : dtng
# tolong : tolong
# sesuaikan : sesuai
# diterima : terima
# puasa : puasa
# senang : senang
# terbantu : bantu
# terburuburu : terburuburu
# klik : klik
# selalu : selalu
# zonk : zonk
# orderan : order
# diantar : antar
# alasan : alas
# mengecewakan : kecewa
# csnya : csnya
# kurirnya : kurir
# sangan : sangan
# informasi : informasi
# quality : quality
# relatif : relatif
# pasaran : pasar
# ya : ya
# berlangganan : langgan
# terus : terus
# hemat : hemat
# irit : irit
# pengeluaran : keluar
# harian : hari
# maju : maju
# berkembang : kembang
# karir : karir
# seperti : seperti
# konvensional : konvensional
# barangbarang : barangbarang
# voucher : voucher
# helpful : helpful
# segariselalu : segariselalu
# baguspenjual : baguspenjual
# tua : tua
# akujdinya : akujdinya
# kenal : kenal
# disini : sini
# depan : depan
# amanah : amanah
# jamin : jamin
# salam : salam
# daerah : daerah
# makassar : makassar
# jabodetabek : jabodetabek
# oke : oke
# membantupengiriman : membantupengiriman
# sebel : sebel
# lemot : lot
# ganti : ganti
# nomor : nomor
# kamar : kamar
# kadang : kadang
# emosi : emosi
# pagi : pagi
# cancel : cancel
# ribet : ribet
# lagi : lagi
# perbaiki : baik
# prlayanan : prlayanan
# lelet : lelet
# barangnya : barang
# ayamnya : ayam
# berlendir : lendir
# kapookk : kapookk
# dpesan : dpesan
# tersedia : sedia
# drefund : drefund
# sumpaah : sumpaah
# dibungkus : bungkus
# rapiiii : rapiiii
# bubble : bubble
# wrap : wrap
# alumunium : alumunium
# foil : foil
# ice : ice
# pack : pack
# dirumah : rumah
# terjaga : jaga
# goodjob : goodjob
# panggah : panggah
# pakkkby : pakkkby
# fitri : fitri
# lampung : lampung
# segarikalo : segarikalo
# fitur : fitur
# mau : mau
# tingkatkan : tingkat
# tracking : tracking
# pembeli : beli
# tahap : tahap
# dipersiapkan : siap
# segaridi : segaridi
# top : top
# markotop : markotop
# kuplit : kuplit
# jogja : jogja
# janji : janji
# pilihan : pilih
# aku : aku
# pergi : pergi
# download : download
# jelajah : jelajah
# try : try
# again : again
# sistemnya : sistem
# update : update
# hahaaaa : hahaaaa
# mitra : mitra
# berbeda : beda
# membeli : beli
# tujuan : tuju
# minyak : minyak
# goreng : goreng
# dikonfirmasi : konfirmasi
# bahwa : bahwa
# mengklaim : klaim
# jujur : jujur
# kecewa : kecewa
# dicancel : dicancel
# berbuat : buat
# kecurangan : curang
# dalam : dalam
# pengembalian : kembali
# ditentukankok : ditentukankok
# ngeri : ngeri
# berbelanja : belanja
# lauknya : lauk
# mempertahankan : tahan
# sistem : sistem
# aneh : aneh
# dulu : dulu
# dikasih : kasih
# ready : ready
# stok : stok
# jadi : jadi
# uangnya : uang
# saya : saya
# kena : kena
# bentuk : bentuk
# poin : poin
# belnja : belnja
# andi : andi
# tangsa : tangsa
# okeh : okeh
# terimakasihbelanja : terimakasihbelanja
# online : online
# membantumempermudahmenyenangkanpokonya : membantumempermudahmenyenangkanpokonya
# bgssegarharganya : bgssegarharganya
# ramahsopan : ramahsopan
# respons : respons
# pertahankan : tahan
# terbaik : baik
# plng : plng
# baikmaju : baikmaju
# success : success
# yuk : yuk
# ikutan : ikut
# disc : disc
# malam : malam
# kerumah : rumah
# set : set
# siang : siang
# pas : pas
# sadar : sadar
# item : item
# totalnya : total
# invoice : invoice
# koin : koin
# bukan : bukan
# kepepet : pepet
# wa : wa
# bilang : bilang
# evaluasi : evaluasi
# melulupesan : melulupesan
# lagiestimasi : lagiestimasi
# dtggimana : dtggimana
# dimasak : masak
# kalau : kalau
# dtgnya : dtgnya
# diatas : atas
# kualitasnya : kualitas
# terjaminkapok : terjaminkapok
# mqntaaaap : mqntaaaap
# dgan : dgan
# tanpa : tanpa
# harus : harus
# keluar : keluar
# mengantar : antar
# ketiga : tiga
# otw : otw
# gc : gc
# timnya : tim
# ontime : ontime
# delivery : delivery
# ditulis : tulis
# lu : lu
# pesenan : sen
# pengecekan : kece
# seabad : abad
# tidak : tidak
# segariproses : segariproses
# best : best
# penambahan : tambah
# alamat : alamat
# titiknya : titik
# tag : tag
# tahunya : tahu
# habis : habis
# kok : kok
# bogor : bogor
# kota : kota
# sedih : sedih
# uhhhh : uhhhh
# dibatalkan : batal
# an : an
# aulia : aulia
# keluhan : keluh
# kedepannya : depan
# pelayanannyasukses : pelayanannyasukses
# packingnya : packingnya
# pilihanmau : pilihanmau
# kosonghabis : kosonghabis
# matiin : matiin
# silakan : sila
# link : link
# pembelian : beli
# ribu : ribu
# jadetabek : jadetabek
# liter : liter
# syarat : syarat
# ketentuannya : tentu
# minimal : minimal
# sembako : sembako
# khusus : khusus
# maret : maret
# buruan : buru
# segariidviafreshmart : segariidviafreshmart
# job : job
# membanyaki : banyak
# diskonnya : diskon
# terhadap : hadap
# pekerjanya : kerja
# sebagai : bagai
# mengenakan : kena
# tarif : tarif
# manusiawi : manusiawi
# dibawah : bawah
# masih : masih
# rp : rp
# perpengiriman : kirim
# jarak : jarak
# maximum : maximum
# kamu : kamu
# diharuskan : harus
# atribut : atribut
# sehrsnya : sehrsnya
# menjd : menjd
# beban : beban
# perusahaan : usaha
# tas : tas
# mengeksploitasi : eksploitasi
# belanjaan : belanja
# pesanannya : pesan
# pokoknya : pokok
# tamah : tamah
# blanja : blanja
# segaritrimakasihsegari : segaritrimakasihsegari
# meringankan : ringan
# pekerjaan : kerja
# tangga : tangga
# recomended : recomended
# kusus : sus
# sibuk : sibuk
# segarisangat : segarisangat
# menghemat : hemat
# uangharga : uangharga
# promoproduk : promoproduk
# hargaselalu : hargaselalu
# pengirimankurir : pengirimankurir
# pengantarnya : antar
# ramahsemoga : ramahsemoga
# adakan : adakan
# mntul : mntul
# melon : melon
# bau : bau
# layak : layak
# dijual : jual
# gue : gue
# maunya : mau
# apasih : apasih
# not : not
# recommended : recommended
# diperluas : luas
# area : area
# sidoarjo : sidoarjo
# surabaya : surabaya
# promosi : promosi
# branding : branding
# merchantnya : merchantnya
# semudah : mudah
# membalikkan : balik
# telapak : telapak
# tangan : tangan
# nice : nice
# kondisi : kondisi
# produkproduk : produkproduk
# mahal : mahal
# murahan : murah
# menjaga : jaga
# thanks : thanks
# fast : fast
# mantaaapsegarsegaar : mantaaapsegarsegaar
# berkali : kali
# durasi : durasi
# bilangnya : bilang
# terdaftar : daftar
# marah : marah
# dasar : dasar
# tipu : tipu
# karena : karena
# tetangga : tetangga
# sewajarnya : wajar
# menyanangkan : menyanangkan
# tokosupermarketyg : tokosupermarketyg
# terpenting : penting
# barngnya : barngnya
# bergaransi : garansi
# masuk : masuk
# cek : cek
# rekening : rekening
# masukan : masuk
# salah : salah
# ajuin : ajuin
# strategi : strategi
# marketing : marketing
# beras : beras
# seharga : harga
# jual : jual
# admin : admin
# copy : copy
# paste : paste
# nya : nya
# klise : klise
# ketersediaan : sedia
# fluktuatif : fluktuatif
# berarti : arti
# ujung : ujung
# capek : capek
# keranjang : keranjang
# pelayananya : pelayananya
# sopan : sopan
# memesan : mes
# dibutuhkan : butuh
# mendadak : dadak
# pengajuan : aju
# ditransfer : transfer
# usaha : usaha
# cepatmenyenangkan : cepatmenyenangkan
# rasional : rasional
# muasin : muasin
# konsumen : konsumen
# perlakuan : laku
# ridernya : ridernya
# sore : sore
# anter : anter
# upahnya : upah
# nextday : nextday
# panen : panen
# apaan : apa
# siangjnngn : siangjnngn
# percumah : percumah
# mari : mari
# hilang : hilang
# timepengepakan : timepengepakan
# safety : safety
# menjangkau : jangkau
# pedalaman : dalam
# malas : malas
# dapurpengiriman : dapurpengiriman
# waktupastinya : waktupastinya
# keterlambatan : lambat
# notifikasi : notifikasi
# vocher : vocher
# terbaekkk : terbaekkk
# memamg : memamg
# dibanding : banding
# shop : shop
# cakeeppp : cakeeppp
# kebangetan : banget
# rider : rider
# tip : tip
# potong : potong
# seratus : ratus
# ratus : ratus
# peraknya : perak
# upah : upah
# customernya : customernya
# bareng : bareng
# datangnya : datang
# packingan : packingan
# higienis : higienis
# lebih : lebih
# beda : beda
# hatata : hatata
# contoh : contoh
# cabai : cabai
# gram : gram
# ku : ku
# bintangklo : bintangklo
# hheee : hheee
# irt : irt
# mager : mager
# jalan : jalan
# saja : saja
# mantab : mantab
# sekalipromo : sekalipromo
# bnykbertanggung : bnykbertanggung
# sombong : sombong
# supermarket : supermarket
# memudahkan : mudah
# dijaga : jaga
# kesegaran : segar
# komplein : komplein
# barusegarpacking : barusegarpacking
# okterutama : okterutama
# ayam : ayam
# aluminium : aluminium
# foilmantapppp : foilmantapppp
# jelek : jelek
# paking : paking
# ekspedisi : ekspedisi
# komitmen : komitmen
# mencoba : coba
# pelanggan : langgan
# next : next
# kabupaten : kabupaten
# tangerang : tangerang
# malang : malang
# kendala : kendala
# buang : buang
# internal : internal
# pecus : cus
# dibayar : bayar
# penyelesaian : selesai
# terlambat : lambat
# sabtu : sabtu
# minggu : minggu
# tungguin : tungguin
# tetap : tetap
# makan : makan
# bangetngga : bangetngga
# bagustp : bagustp
# app : app
# nyaman : nyaman
# rumahdan : rumahdan
# namanya : nama
# segarisemua : segarisemua
# menyelesaikan : selesai
# persulit : sulit
# akun : akun
# no : no
# dll : dll
# canggih : canggih
# selamat : selamat
# favorite : favorite
# perlua : perlua
# sat : sat
# perluas : luas
# wilayahnya : wilayah
# freesssmantulll : freesssmantulll
# memuaskanpelayanan : memuaskanpelayanan
# cepatproduknya : cepatproduknya
# sihudah : sihudah
# mesen : mesen
# jamgiliran : jamgiliran
# pesenannya : sen
# dikirimjelek : dikirimjelek
# sumpah : sumpah
# enggak usah : enggak usah
# downlod : downlod
# menyesal : sesal
# itupun : itu
# uangkan : uang
# koinnya : koin
# baca : baca
# ketentuan : tentu
# rugikan : rugi
# mengantarannya : antar
# paket : paket
# titik : titik
# cat : cat
# tembok : tembok
# warna : warna
# hijau : hijau
# kekeh : kekeh
# kakak : kakak
# ketik : ketik
# hadeh : hadeh
# adek : adek
# ambl : ambl
# kepuasan : puas
# tulis : tulis
# dicek : cek
# trmksh : trmksh
# mendarat : darat
# sanggar : sanggar
# permintaan : minta
# jaga : jaga
# salada : salada
# kegemaran : gemar
# ragu : ragu
# diaayangkan : diaayangkan
# akses : akses
# lonjakan : lonjak
# diluar : luar
# minat : minat
# disayangkan : sayang
# terpercaya : percaya
# perdagangan : dagang
# sebelumnya : belum
# layanannya : layan
# benaran : benar
# diperbaiki : baik
# plis : plis
# usah : usah
# loved : loved
# lambat : lambat
# logout : logout
# delifery : delifery
# stars : stars
# quick : quick
# response : response
# pisang : pisang
# packsemua : packsemua
# busukbingungklo : busukbingungklo
# dikirimapa : dikirimapa
# control : control
# mestinya : mesti
# jualannya : jual
# mesti : mesti
# freshtp : freshtp
# semuamales : semuamales
# lgzzzzzzzzzzz : lgzzzzzzzzzzz
# mulu : mulu
# diantarnya : antar
# sokan : sok
# bisanya : bisa
# bicara : bicara
# mengesankan : kesan
# konsisten : konsisten
# diinformasikan : informasi
# bangetttmaksish : bangetttmaksish
# alamatnya : alamat
# diedit : edit
# petanya : peta
# ngawur : ngawur
# ngeloading : ngeloading
# ngelacak : ngelacak
# wow : wow
# jawa : jawa
# timur : timur
# terima kasih : terima kasih
# jangkaui : jangkau
# dimana : mana
# tertarik : tarik
# bandungg : bandungg
# wilayah : wilayah
# menggila : gila
# lancar : lancar
# solusi : solusi
# jarang : jarang
# didepan : depan
# maa : maa
# syaa : syaa
# allah : allah
# hematsuper : hematsuper
# puasbelanja : puasbelanja
# fressdi : fressdi
# id : id
# sweaty : sweaty
# chekout : chekout
# pembayaran : bayar
# eror : eror
# kah : kah
# alpukat : alpukat
# mentega : mentega
# kanzler : kanzler
# enak : enak
# berkualitas : kualitas
# bermutu : mutu
# alpuket : alpuket
# kagak : kagak
# mateng : mateng
# thebest : thebest
# tingkat : tingkat
# lauk : lauk
# laris : laris
# manis : manis
# amin : amin
# pilnm : pilnm
# gabriel : gabriel
# ecclesias : ecclesias
# terjangkaupengiriman : terjangkaupengiriman
# kardus : kardus
# medan : medan
# mohon : mohon
# masyarakat : masyarakat
# mempermasalahkan : masalah
# letak : letak
# lokasinya : lokasi
# muter : muter
# kualitasnyasemoga : kualitasnyasemoga
# molor : molor
# ber : ber
# kepalang : kepalang
# brn : brn
# kesini : kesini
# tlngbdi : tlngbdi
# grtis : grtis
# pngriman : pngriman
# nympe : nympe
# trimakasiihh : trimakasiihh
# buahbuahan : buahbuahan
# telurtapi : telurtapi
# telurnya : telur
# bagusgpplah : bagusgpplah
# tambahan : tambah
# gampang : gampang
# uninstall : uninstall
# buka : buka
# kadangkadang : kadangkadang
# error : error
# pengantarannya : antar
# masyaaallah : masyaaallah
# segarsegar : segarsegar
# membantukeren : membantukeren
# tksh : tksh
# dapur : dapur
# dkirim : dkirim
# komunikatif : komunikatif
# persediaan : sedia
# bon : bon
# dicampur : campur
# sd : sd
# donktapi : donktapi
# gkngutamain : gkngutamain
# dipertahankan : tahan
# verifikasinyatunggu : verifikasinyatunggu
# sms : sms
# untuk : untuk
# pin : pin
# kluarjadi : kluarjadi
# plus : plus
# gratis : gratis
# kecil : kecil
# rutin : rutin
# ngebuka : ngebuka
# menu : menu
# tampilan : tampil
# bukangedip : bukangedip
# gerak : gerak
# diemtp : diemtp
# ngedip : ngedip
# instal : instal
# gunain : gunain
# heran : heran
# halal : halal
# di : di
# install : install
# kenapa : kenapa
# diklik : klik
# kedip : kedip
# dipakai : pakai
# bagusfres : bagusfres
# is : is
# membingungkan : bingung
# disederhanakan : sederhana
# menyenangkan : senang
# deteksi : deteksi
# lokasi : lokasi
# memantau : pantau
# mnimal : mnimal
# saingan : saing
# maybe : maybe
# pengkategorian : kategori
# konsekuen : konsekuen
# praktisdgn : praktisdgn
# pada : pada
# pengguna : guna
# main : main
# titip : titip
# kain : kain
# keterngn : keterngn
# penerima : terima
# bukti : bukti
# foto : foto
# penerimanya : terima
# kesel : kesel
# dadakan : dada
# dagangan : dagang
# panik : panik
# sih : sih
# membantuku : bantu
# thnks : thnks
# love : love
# mempermudah : mudah
# segarayam : segarayam
# fresbgus : fresbgus
# kulkas : kulkas
# pelit : pelit
# happy : happy
# gajih : gajih
# sok : sok
# far : far
# setianya : setia
# perfect : perfect
# services : services
# keperluan : perlu
# perlukan : perlu
# semua : semua
# diakses : akses
# dipahami : paham
# kalangan : kalang
# terjamin : jamin
# all : all
# clear : clear
# apps : apps
# bantu : bantu
# kaum : kaum
# rebahan : rebah
# antri : antri
# supermarketpasarmudah : supermarketpasarmudah
# penggunaan : guna
# diswalayan : swalayan
# cptpacking : cptpacking
# rapiamanharga : rapiamanharga
# murahbrg : murahbrg
# berkualitasmas : berkualitasmas
# ramahtetap : ramahtetap
# nyatq : nyatq
# dikabarin : dikabarin
# berjam : jam
# dibayarkan : bayar
# eh : eh
# bloon : bloon
# merugikan : rugi
# telor : telor
# pecah : pecah
# butir : butir
# double : double
# modal : modal
# lakban : lakban
# kayak : kayak
# tempatnya : tempat
# dasarnya : dasar
# lo : lo
# dedline : dedline
# kemasan : kemas
# loch : loch
# buahannya : buah
# matang : matang
# digantikan : ganti
# dikirimkan : kirim
# posisi : posisi
# mentah : mentah
# pematangan : pematang
# mencari : cari
# pangan : pangan
# butuhkan : butuh
# mantulll : mantulll
# mudahan : mudah
# jabotabek : jabotabek
# freshbanyak : freshbanyak
# nyatingkatkan : nyatingkatkan
# thank : thank
# you : you
# berkalikali : berkalikali
# banyak : banyak
# kunjung : kunjung
# brokoli : brokoli
# dipaksa : paksa
# pepaya : pepaya
# muda : muda
# kuning : kuning
# dalamnya : dalam
# instan : instan
# ekonomis : ekonomis
# dibanyakin : dibanyakin
# perbanyak : banyak
# dibatasi : batas
# digabung : gabung
# cepatsaya : cepatsaya
# sejahtera : sejahtera
# riderdi : riderdi
# bawa : bawa
# besarnamun : besarnamun
# kesejahtera : sejahtera
# motor : motor
# adaperaturan : adaperaturan
# ketatbonus : ketatbonus
# kpi : kpi
# kecilbpjs : kecilbpjs
# minbelanja : minbelanja
# bagusbuahnya : bagusbuahnya
# basah : basah
# robek : robek
# menguranggi : menguranggi
# saguran : sagur
# kafi : kafi
# uninstal : uninstal
# mengecek : ecek
# kectambun : kectambun
# selatan : selatan
# keljatimulya : keljatimulya
# tercover : tercover
# dahlah : dah
# sayurbox : sayurbox
# lucu : lucu
# tentuin : tentuin
# stock : stock
# tanggal : tanggal
# wkwkwk : wkwkwk
# lumayan : lumayan
# sedikit : sedikit
# kayaknya : kayak
# niat : niat
# berhemat : hemat
# tekorrr : tekorrr
# doang : doang
# puasbarang : puasbarang
# rusak : rusak
# kembli : kembli
# kecuali : kecuali
# dibeli : beli
# masalh : masalh
# memakan : makan
# berhari : hari
# ingat : ingat
# bos : bos
# diobatin : diobatin
# sudahlah : sudah
# sebelom : bom
# gede : gede
# enggak mau : enggak mau
# nominal : nominal
# syaratnya : syarat
# freshmurah : freshmurah
# bagusfree : bagusfree
# secepat : cepat
# cool : cool
# nipu : nipu
# bgtpromonya : bgtpromonya
# boongpas : boongpas
# cout : cout
# hadiah : hadiah
# cust : cust
# takut : takut
# hem : hem
# tulisannya : tulis
# pejeng : jeng
# freshsegar : freshsegar
# layu : layu
# maks : maks
# dijanjiin : dijanjiin
# kodenya : kode
# diterbitkan : terbit
# besoknya : besok
# follow : follow
# up : up
# jawabannya : jawab
# nagih : nagih
# begini : begini
# kabar : kabar
# mengerti : erti
# dieskalasi : eskalasi
# permohonan : mohon
# penerbitan : terbit
# harusny : harusny
# sla : sla
# kentanga : kentanga
# sayursayuran : sayursayuran
# tradisional : tradisional
# pengemasannya : emas
# waktucuman : waktucuman
# kumplitcoba : kumplitcoba
# perkumplit : perkumplit
# otomatis : otomatis
# gayanya : gaya
# giliran : gilir
# hahah : hahah
# padahal : padahal
# haha : haha
# yasudah : yasudah
# hapus : hapus
# enggak jelas : enggak jelas
# depok : depok
# ngirimnya : ngirimnya
# datang : datang
# tanya : tanya
# kuririnya : kurir
# mobil : mobil
# pusat : pusat
# sayurny : sayurny
# sayurikan : sayurikan
# productnya : productnya
# amandibungkus : amandibungkus
# gel : gel
# nyakurirnya : nyakurirnya
# insyaallah : insyaallah
# jakarta : jakarta
# kesal : kesal
# aneka : aneka
# protein : protein
# hewani : hewani
# pokokny : pokokny
# dsegari : dsegari
# pelayananny : pelayananny
# lunas : lunas
# esok : esok
# harinya : hari
# refundnya : refundnya
# maksa : maksa
# dibalikin : dibalikin
# via : via
# ovo : ovo
# pity : pity
# prima : prima
# tama : tama
# datengnya : datengnya
# dekat : dekat
# dzuhur : dzuhur
# ketagihan : tagih
# disegarii : gari
# kecewaa : kecewaa
# belanjakan : belanja
# awet : awet
# kerennnnnnn : kerennnnnnn
# seru : seru
# ekspektasi : ekspektasi
# syuka : syuka
# freshpengiriman : freshpengiriman
# wajar : wajar
# santai : santai
# tiduran : tidur
# eksekusi : eksekusi
# ongkos : ongkos
# parkir : parkir
# bensinmacet : bensinmacet
# akui : aku
# satuny : satuny
# ordernya : order
# rencana : rencana
# gagal : gagal
# cari : cari
# alternatif : alternatif
# merepotkan : repot
# dipasang : pasang
# gara : gara
# sebenarnya : benar
# mencapai : capai
# minimum : minimum
# trm : trm
# salad : salad
# butuhin : butuhin
# sangat : sangat
# mmbantu : mmbantu
# hanya : hanya
# syur : syur
# buahnyapun : buah
# sni : sni
# tebus : tebus
# jugangga : jugangga
# taunya : tau
# cenderung : cenderung
# bgstipis : bgstipis
# putih : putih
# aroma : aroma
# sedap : sedap
# alias : alias
# atau : atau
# konfirmasinya : konfirmasi
# ataw : ataw
# standar : standar
# puaas : puaas
# muraaah : muraaah
# mereferalkan : mereferalkan
# data : data
# benefit : benefit
# apapun : apa
# direferalkan : direferalkan
# menyambung : sambung
# fikir : fikir
# ribuan : ribu
# layanannyasaya : layanannyasaya
# mayur : mayur
# sayangkan : sayang
# neglasari : neglasari
# memuaskanselain : memuaskanselain
# kemas : kemas
# jajal : jajal
# dluklo : dluklo
# full : full
# keempat : empat
# entah : entah
# andalkankalau : andalkankalau
# nama : nama
# tokonyacpt : tokonyacpt
# pengirimanya : pengirimanya
# pgudh : pgudh
# dtngapa : dtngapa
# bonus : bonus
# nyasenang : nyasenang
# kecepatan : cepat
# jantung : jantung
# sunguh : sunguh
# dengan : dengan
# segeerr : segeerr
# terkirim : kirim
# diselesaikan : selesai
# nyama : nyama
# dikemas : kemas
# penasaran : penasaran
# bedanya : beda
# hehehe : hehehe
# sori : sori
# cuma : cuma
# bgusss : bgusss
# dikit : dikit
# gapapa : gapapa
# masya : masya
# kalinya : kali
# turun : turun
# sanggup : sanggup
# range : range
# jamnya : jam
# mengasih : asih
# duh : duh
# ngaruh : ngaruh
# amanbarang : amanbarang
# xxxx : xxxx
# sorry : sorry
# adalah : adalah
# makanan : makan
# oederan : oederan
# kupesan : pes
# agst : agst
# dikonsumsi : konsumsi
# kadaluarsaexp : kadaluarsaexp
# jangan : jangan
# dong : dong
# mknan : mknan
# bahaya : bahaya
# konsumenpembeli : konsumenpembeli
# semuah : semuah
# penolong : tolong
# disaat : saat
# pendemi : demi
# laku : laku
# kerassemoga : kerassemoga
# goodcocok : goodcocok
# masakan : masakan
# grade : grade
# istimewa : istimewa
# overload : overload
# diubahjangan : diubahjangan
# pago : pago
# ati : ati
# biru : biru
# komsumsi : komsumsi
# jeruk : jeruk
# isi : isi
# pcs : pcs
# merugi : rugi
# cirebon : cirebon
# pelayannya : layan
# discount : discount
# direfund : direfund
# kejelasan : jelas
# detail : detail
# kacau : kacau
# balau : balau
# first : first
# impression : impression
# recommend : recommend
# yall : yall
# use : use
# this : this
# enggak tau : enggak tau
# duit : duit
# kabarnya : kabar
# such : such
# scammer : scammer
# haram : haram
# diprbaiki : diprbaiki
# tf : tf
# binta : binta
# minus : minus
# muh : muh
# farhan : farhan
# setiawan : setiawan
# karawaci : karawaci
# mood : mood
# udhx : udhx
# shampo : shampo
# ditrasfer : ditrasfer
# dijadikan : jadi
# voucer : voucer
# memaafi : maaf
# persis : persis
# bertambah : tambah
# lakukansy : lakukansy
# kenes : kenes
# hati : hati
# alfafreshsdh : alfafreshsdh
# sebulan : bulan
# mamam : mamam
# ribuga : ribuga
# solusinya : solusi
# mikir : mikir
# goodpengiriman : goodpengiriman
# bahannyasegar : bahannyasegar
# dijadwalkan : jadwal
# slow : slow
# terhambat : hambat
# share : share
# ajak : ajak
# join : join
# diinfo : info
# merekomendasikan : rekomendasi
# respek : respek
# dunia : dunia
# perdapuran : dapur
# areanya : area
# hihihihi : hihihihi
# freeeeesshhhh : freeeeesshhhh
# bawang : bawang
# merah : merah
# isinya : isi
# much : much
# rrr : rrr
# lsung : lsung
# gercep : gercep
# iklannya : iklan
# bohongan : bohong
# size : size
# appnya : appnya
# mbak : mbak
# tim : tim
# developernya : developer
# optimalkan : optimal
# diantarantar : diantarantar
# seenak : enak
# jidat : jidat
# direspon : direspon
# daftar : daftar
# teror : teror
# mubajirbeli : mubajirbeli
# embel : embel
# belanjaorg : belanjaorg
# risih : risih
# donwload : donwload
# keatas : atas
# tertera : tera
# patokan : patok
# dipermudah : mudah
# payah : payah
# ah : ah
# dikab : dikab
# lohsy : lohsy
# weleehhhh : weleehhhh
# malihmohon : malihmohon
# cover : cover
# andaikan : andai
# pengirimansayangnya : pengirimansayangnya
# tibatiba : tibatiba
# kekangkauada : kekangkauada
# berturutturut : berturutturut
# siniya : siniya
# rapii : rapi
# nyeselll : nyeselll
# ini : ini
# andai : andai
# taugmn : taugmn
# melebihi : lebih
# bayaran : bayar
# pangkas : pangkas
# perubahan : ubah
# peraturan : atur
# lagiyg : lagiyg
# atasannya : atas
# panasan : panas
# hujan : hujan
# hujananmasih : hujananmasih
# dipotongbahkan : dipotongbahkan
# menyepelekan : sepele
# istri : istri
# cobaeh : cobaeh
# iki : iki
# luas : luas
# pengeirimannya : pengeirimannya
# berkurang : kurang
# entar : entar
# diupdate : diupdate
# bintangnya : bintang
# konfirm : konfirm
# jasa : jasa
# dipakenya : dipakenya
# paketnya : paket
# nyasar : nyasar
# oiya : oiya
# membatalkan : batal
# sayurandan : sayurandan
# hari : hari
# esokan : esok
# setia : setia
# batas : batas
# biji : biji
# manee : manee
# sebelum : belum
# ksong : ksong
# malah : malah
# smaa : smaa
# tajur : tajur
# halang : halang
# yahudh : yahudh
# ajahdari : ajahdari
# orderkatanya : orderkatanya
# segaritolong : segaritolong
# penjelasannyauntuk : penjelasannyauntuk
# bosan : bosan
# serlock : serlock
# telepon : telepon
# keder : keder
# macam : macam
# pengebalian : balian
# menangani : tangan
# seninrabu : seninrabu
# dananya : dana
# nanganin : nanganin
# simple : simple
# mutu : mutu
# ribeeeetjadi : ribeeeetjadi
# mitranya : mitra
# ribeeeet : ribeeeet
# omzet : omzet
# juta : juta
# flexi : flexi
# komisiget : komisiget
# hilangno : hilangno
# amal : amal
# sedekah : sedekah
# tulisan : tulis
# bagussegar : bagussegar
# receh : receh
# nilainya : nilai
# cakupan : cakup
# daeran : daeran
# tambun : tambun
# utara : utara
# asli : asli
# brgnya : brgnya
# segarpengiriman : segarpengiriman
# lamakelamaan : lamakelamaan
# pusing : pusing
# bolakbalik : bolakbalik
# mengatur : atur
# ujungujungnya : ujungujungnya
# bagussemoga : bagussemoga
# lagisukses : lagisukses
# berkah : berkah
# rada : rada
# padamu : pada
# bagusbanyak : bagusbanyak
# diskonan : diskon
# timbangannya : timbang
# disitu : situ
# debit : debit
# mutasi : mutasi
# tunjukkan : tunjuk
# dikabari : kabar
# dsuruh : dsuruh
# balikin : balikin
# transferan : transfer
# bertele : tele
# bahannye : bahannye
# komplen : komplen
# dikembaliin : dikembaliin
# seharian : hari
# ayo : ayo
# pastinya : pasti
# servicenya : servicenya
# manusia : manusia
# robot : robot
# chatting : chatting
# exelent : exelent
# puassyurna : puassyurna
# segarn : segarn
# bertahan : tahan
# lamasy : lamasy
# akan : akan
# ajsyurna : ajsyurna
# organikjd : organikjd
# hewanina : hewanina
# kesegarannyan : kesegarannyan
# pasaransukses : pasaransukses
# semangat : semangat
# belanjaehh : belanjaehh
# segaripadahal : segaripadahal
# jugabuat : jugabuat
# secepatnya : cepat
# jangkau : jangkau
# sihtapi : sihtapi
# kentang : kentang
# busukdan : busukdan
# keciiiil : keciiiil
# laindan : laindan
# jamtadi : jamtadi
# payahhh : payahhh
# exp : exp
# memikat : mikat
# daya : daya
# tarik : tarik
# benarbenar : benarbenar
# kemasannya : kemas
# dijanjikan : janji
# membantuu : membantuu
# freshlangganan : freshlangganan
# sinibanyak : sinibanyak
# pulathanks : pulathanks
# bonusan : bonus
# sayurdagingbuah : sayurdagingbuah
# fresssangat : fresssangat
# dagingnya : daging
# packagingnya : packagingnya
# komplit : komplit
# ink : ink
# terkemas : kemas
# alangkah : alangkah
# posting : posting
# selesai : selesai
# membayar : bayar
# kesan : kesan
# auto : auto
# nyahehehe : nyahehehe
# lncar : lncar
# profesional : profesional
# ketepatannya : tepat
# alhamdulilah : alhamdulilah
# dipilihkan : pilih
# murahhhhdpt : murahhhhdpt
# degan : degan
# puasproduknya : puasproduknya
# aa : aa
# frees : frees
# disuruh : suruh
# diakun : akun
# ajukan : aju
# oktapi : oktapi
# custjadi : custjadi
# apa : apa
# bekasi : bekas
# dperluas : dperluas
# jaringannya : jaring
# kelanjutannya : lanjut
# sihtambah : sihtambah
# ibutapi : ibutapi
# buahanya : buahanya
# mbantu : mbantu
# kerjasama : kerjasama
# alfafresh : alfafresh
# lamaa : lamaa
# terbaru : baru
# diinstal : diinstal
# phising : phising
# gaes : gaes
# scroll : scroll
# korban : korban
# nyakebetulan : nyakebetulan
# sekian : sekian
# gonta : gonta
# melulu : melulu
# hadehhh : hadehhh
# pertamasy : pertamasy
# gbng : gbng
# uwow : uwow
# pemenang : menang
# employee : employee
# of : of
# month : month
# disegaribelanja : disegaribelanja
# nanyain : nanyain
# ujan : ujan
# cerah : cerah
# rugi : rugi
# yakalee : yakalee
# fressghh : fressghh
# fastrespon : fastrespon
# frozen : frozen
# pengepakannya : epak
# seringsering : seringsering
# bagikan : bagi
# penjelasan : jelas
# keseringan : sering
# lengkapujungnya : lengkapujungnya
# diperbaikiuang : diperbaikiuang
# direfundkl : direfundkl
# kosongjd : kosongjd
# ditempat : tempat
# lainapa : lainapa
# controlnya : controlnya
# mitranyatidak : mitranyatidak
# timbal : timbal
# mitrakerja : mitrakerja
# bakti : bakti
# kayamitra : kayamitra
# gempor : gempor
# jualan : jual
# dihargai : harga
# teken : teken
# subuh : subuh
# kabur : kabur
# alhasil : alhasil
# dijamin : jamin
# xixixixiiii : xixixixiiii
# diperhatikan : perhati
# kesejahteraan : sejahtera
# iya : iya
# makasoy : makasoy
# sayurnyamantap : sayurnyamantap
# segaribisa : segaribisa
# warung : warung
# segarieh : segarieh
# adminnya : adminnya
# segarihadeuh : segarihadeuh
# ngenes : ngenes
# klop : klop
# yaudah : yaudah
# pikir : pikir
# lho : lho
# qurma : qurma
# ajwa : ajwa
# banyakan : banyak
# jenis : jenis
# buat : buat
# sekalidua : sekalidua
# akal : akal
# dilipat : lipat
# plastik : plastik
# tempel : tempel
# seumur : umur
# complaint : complaint
# servive : servive
# produkny : produkny
# bagusttp : bagusttp
# bgssaya : bgssaya
# mudahn : mudahn
# yapengiriman : yapengiriman
# nyq : nyq
# abang : abang
# dibawa : bawa
# heeeeerbbbbbbaaaat : heeeeerbbbbbbaaaat
# imperfect : imperfect
# dimakan : makan
# hargai : harga
# amsn : amsn
# ngadi : ngadi
# mam : mam
# ikannya : ikan
# cepatlah : cepat
# segerseger : segerseger
# sygkn : sygkn
# menikmti : menikmti
# jangkauany : jangkauany
# promoongkir : promoongkir
# gratishadiah : gratishadiah
# blaja : blaja
# kecwanyarefund : kecwanyarefund
# invoicenya : invoicenya
# refundchat : refundchat
# kaya : kaya
# jawabnya : jawab
# seting : ting
# belipernah : belipernah
# omelin : omelin
# hoax : hoax
# pajang : pajang
# segariidwarungelsha : segariidwarungelsha
# segarimantap : segarimantap
# pernah : pernah
# perkiraan : kira
# komisi : komisi
# dipajang : pajang
# yes : yes
# perdana : perdana
# hematfresh : hematfresh
# sayurannyadapet : sayurannyadapet
# segerrr : segerrr
# semuaa : semuaa
# membatu : batu
# mengkel : mengkel
# deskripsi : deskripsi
# gambar : gambar
# bagussegardan : bagussegardan
# aaaahh : aaaahh
# kehadiran : hadir
# daaan : daaan
# amazingnya : amazingnya
# lot : lot
# and : and
# founder : founder
# gojek : gojek
# sampenya : sampenya
# waktusemua : waktusemua
# standartpokoknya : standartpokoknya
# segerbuahnya : segerbuahnya
# sayuranbuahayam : sayuranbuahayam
# variatif : variatif
# kwalitasnya : kwalitasnya
# bagusterima : bagusterima
# ganggu : ganggu
# infooo : infooo
# iye : iye
# iyeee : iyeee
# serah : serah
# malesssssss : malesssssss
# kantongfres : kantongfres
# apikasi : apikasi
# tida : tida
# belanjaterimakadih : belanjaterimakadih
# infokan : info
# prodyk : prodyk
# fressh : fressh
# makasiih : makasiih
# segarii : gari
# larisss : larisss
# pintubarang : pintubarang
# antar : antar
# kinerja : kerja
# komplainnya : komplain
# terimskasih : terimskasih
# tcc : tcc
# gvwr : gvwr
# untung : untung
# kecewakesalahan : kecewakesalahan
# dikorbankanbisanya : dikorbankanbisanya
# sistemmaafuang : sistemmaafuang
# direfundcoba : direfundcoba
# belajar : ajar
# bertanggung : tanggung
# customersudah : customersudah
# uninstallmasih : uninstallmasih
# sejenis : jenis
# menghargai : harga
# boikot : boikot
# india : india
# semuatrmksh : semuatrmksh
# gregetan : gregetan
# bbrapa : bbrapa
# bayarnya : bayar
# blanjaan : blanjaan
# pintar : pintar
# menerus : terus
# megaria : megaria
# invite : invite
# referal : referal
# pengirim : kirim
# bu : bu
# segaribnyak : segaribnyak
# promokulkas : promokulkas
# penuh : penuh
# trsbrg : trsbrg
# jgpengiriman : jgpengiriman
# complain : complain
# dsepelekan : dsepelekan
# bijak : bijak
# cocok : cocok
# pemburu : buru
# segarikualitasnya : segarikualitasnya
# berbagi : bagi
# utamakan : utama
# memuaskanpengiriman : memuaskanpengiriman
# baranganya : baranganya
# sreg : sreg
# disenangi : nang
# lawan : lawan
# iloveyou : iloveyou
# mantaappp : mantaappp
# pagii : pagi
# fan : fan
# sayurana : sayurana
# nilai : nilai
# menariknya : tarik
# aplikasiwebsite : aplikasiwebsite
# mata : mata
# bungkuskemasan : bungkuskemasan
# sempurna : sempurna
# like : like
# diaplikasi : aplikasi
# more : more
# better : better
# sah : sah
# duduk : duduk
# pelanan : pelan
# diragukan : ragu
# kebersihannya : bersih
# segarisayurnya : segarisayurnya
# diskaz : diskaz
# menyukai : suka
# bangetpuas : bangetpuas
# dipasar : pasar
# bebas : bebas
# efisien : efisien
# bagis : bagis
# pribadi : pribadi
# cuan : cuan
# mantapcuma : mantapcuma
# dipengirimannya : kirim
# timbangan : timbang
# inicepat : inicepat
# pembelanjaan : belanja
# pengurangan : kurang
# mengira : ira
# kehitungnya : hitung
# hitung : hitung
# manual : manual
# kab : kab
# praktislengkap : praktislengkap
# amazing : amazing
# praktissss : praktissss
# dipesan : pes
# menyajikannya : saji
# pembayarannya : bayar
# mandiri : mandiri
# telp : telp
# nanti : nanti
# acar : acar
# tranfer : tranfer
# minyaknya : minyak
# adaudah : adaudah
# garansi : garansi
# ditunggu : tunggu
# ginihari : ginihari
# balesan : balesan
# jem : jem
# god : god
# gambarnya : gambar
# keterangan : terang
# ruang : ruang
# geraknya : gerak
# memuasakan : puasa
# sopancuma : sopancuma
# macamjenisnya : macamjenisnya
# memiliki : milik
# batita : batita
# kampung : kampung
# kntong : kntong
# dipotong : potong
# ringkas : ringkas
# psr : psr
# prosesnya : proses
# sampaiserta : sampaiserta
# segardan : gardan
# bagusharga : bagusharga
# masuknya : masuk
# log : log
# loading : loading
# responsif : responsif
# vocer : vocer
# memasukkan : masuk
# budek : budek
# nge : nge
# komplenan : komplenan
# batalan : batal
# cepatpuassss : cepatpuassss
# nyesal : nyesal
# kurrir : kurrir
# persentasenya : persentase
# dipangkas : pangkas
# kesulitan : sulit
# perhatikan : perhati
# trimksh : trimksh
# belanjapacking : belanjapacking
# hewanisegarexp : hewanisegarexp
# date : date
# jauhdipertahankan : jauhdipertahankan
# over : over
# fressayur : fressayur
# waktuhemat : waktuhemat
# garansinya : garansi
# dan : dan
# bangetrecomen : bangetrecomen
# seller : seller
# etalase : etalase
# cantumkan : cantum
# simpan : simpan
# murah meriah : murah riah
# murahh : murahh
# sangaaat : sangaaat
# puaaas : puaaas
# buaah : buaah
# sopan  : sopan
# kebagian : bagi
# sisa : sisa
# kebiasaan : biasa
# refundkecewa : refundkecewa
# berat : berat
# tdkkonfirmasi : tdkkonfirmasi
# dikurangidicancel : dikurangidicancel
# tersebut : sebut
# confirmnya : confirmnya
# berbelanjabarangnya : berbelanjabarangnya
# bagussuka : bagussuka
# sayuranya : sayuranya
# codkurir : codkurir
# tugas : tugas
# mengantarpas : mengantarpas
# haduuhh : haduuhh
# mudahtinggal : mudahtinggal
# kurangi : kurang
# nyasebaiknya : nyasebaiknya
# teliti : teliti
# pagipagi : pagipagi
# kupas : kupas
# iris : iris
# senangnya : senang
# segaribarangnya : segaribarangnya
# freshmasak : freshmasak
# resep : resep
# jugadan : jugadan
# promonyaterima : promonyaterima
# segaribarang : segaribarang
# segarterbantu : segarterbantu
# ramahharga : ramahharga
# recomend : recomend
# kabarin : kabarin
# kecawa : kecawa
# penipuan : tipu
# always : always
# fresssukses : fresssukses
# harusnya : harus
# cabe : cabe
# jamur : jamur
# minim : minim
# simpel : simpel
# potongan : potong
# dani : dan
# peking : peking
# syurannya : syur
# apel : apel
# ayamsayurannya : ayamsayurannya
# gaji : gaji
# turunin : turunin
# nganter : nganter
# absen : absen
# efesiensi : efesiensi
# efektifitas : efektifitas
# hebat : hebat
# teruskan : terus
# kinerjanya : kerja
# kita : kita
# cekot : cekot
# bacaan : baca
# anjing : anjing
# nambahin : nambahin
# dosa : dosa
# tanihub : tanihub
# aing : aing
# bad : bad
# barat : barat
# bandung : bandung
# cashback : cashback
# sekaliklo : sekaliklo
# syukron : syukron
# jazakallah : jazakallah
# usahanya : usaha
# tangisin : tangisin
# anaknya : anak
# sangaattt : sangaattt
# masyaallah : masyaallah
# bestt : bestt
# dilengkapi : lengkap
# rapihsayurnya : rapihsayurnya
# massa : massa
# samperin : samperin
# dtgramah : dtgramah
# istikamah : istikamah
# biah : biah
# menunya : menu
# tambahkan : tambah
# halalannya : halal
# besarnya : besar
# rapisayuran : rapisayuran
# bagussangat : bagussangat
# dkk : dkk
# praktisutk : praktisutk
# prtama : prtama
# mudh : mudh
# berlanjut : lanjut
# diskonya : disko
# sekalidan : sekalidan
# sempat : sempat
# kepasarditunggu : kepasarditunggu
# terpenuhi : penuh
# meriah : riah
# buahya : buahya
# padahly : padahly
# terpaksa : paksa
# mskipun : mskipun
# blnj : blnj
# mls : mls
# cepatyg : cepatyg
# lihatnya : lihat
# pkkoknya : pkkoknya
# bagusjd : bagusjd
# belanjanysemoga : belanjanysemoga
# acara : acara
# diskonny : diskonny
# banyk : banyk
# sekli : sekli
# tagihan : tagih
# inovice : inovice
# baguspertshanakan : baguspertshanakan
# mumer : mumer
# madya : madya
# dipercepat : cepat
# bagi : bagi
# pres : pres
# maksimum : maksimum
# trgantikan : trgantikan
# sekali : sekali
# cepatt : cepatt
# seribu : ribu
# alesan : alesan
# disinj : disinj
# tertipu : tipu
# lengkapin : lengkapin
# belaja : baja
# makim : makim
# bro : bro
# jempolan : jempol
# puasss : puasss
# checkout : checkout
# minimarket : minimarket
# eeh : eeh
# kwalotas : kwalotas
# mini : mini
# market : market
# sangar : sangar
# ongkirnya : ongkirnya
# wkwkwkw : wkwkwkw
# beres : beres
# but : but
# jngkauannya : jngkauannya
# progress : progress
# berjalan : jalan
# situasi : situasi
# memuaskandan : memuaskandan
# mengantarkan : antar
# suami : suami
# sip : sip
# dibuka : buka
# internet : internet
# kencang : kencang
# koneksi : koneksi
# lacak : lacak
# komen : komen
# kenyataan : nyata
# pengirimanbuat : pengirimanbuat
# referral : referral
# cairin : cairin
# ig : ig
# mengapai : kapai
# ittp : ittp
# supplier : supplier
# varian : varian
# mengantri : antri
# ajagratis : ajagratis
# lebaran : lebaran
# terlur : terlur
# sekalisehari : sekalisehari
# trf : trf
# omset : omset
# grill : grill
# kapan : kapan
# moga : moga
# lamapesen : lamapesen
# kmudian : kmudian
# disuka : suka
# sangatt : sangatt
# sayangankn : sayangankn
# setlah : set
# ingginkan : ingginkan
# kosonghabits : kosonghabits
# kata : kata
# melawak : lawak
# sayangankan : sayangankan
# pekerja : kerja
# personal : personal
# bangeeeeeet : bangeeeeeet
# sampenyaterus : sampenyaterus
# belanjaanya : belanjaanya
# bgtharga : bgtharga
# worthit : worthit
# bangetpengemasan : bangetpengemasan
# bgtaku : bgtaku
# food : food
# disiniaku : sia
# banyaksukses : banyaksukses
# parkcoy : parkcoy
# adaini : adaini
# ajasemua : ajasemua
# kebth : kebth
# tersedialengkapcepatmurah : tersedialengkapcepatmurah
# freshhhh : freshhhh
# semuanta : semuanta
# bersahabat : sahabat
# mantabbb : mantabbb
# mantappengiriman : mantappengiriman
# rapihkurir : rapihkurir
# ramahtrims : ramahtrims
# bingung : bingung
# tkng : tkng
# libur : libur
# mudik : mudik
# baby : baby
# ahir : ahir
# beraktivitas : aktivitas
# ykulir : ykulir
# ramahmantapksh : ramahmantapksh
# matapp : matapp
# buahsayurdan : buahsayurdan
# nyatapi : nyatapi
# ramai : ramai
# segaripenjualnya : segaripenjualnya
# terorganisirmiring : terorganisirmiring
# johg : johg
# bohong : bohong
# nyabenar : nyabenar
# tempatdagingbuahsayurmaknyus : tempatdagingbuahsayurmaknyus
# mantull : mantull
# cuman : cuman
# daun : daun
# kemangi : kemangi
# overall : overall
# siii : siii
# blanjay : blanjay
# digunakanbuahnya : digunakanbuahnya
# pasarduduk : pasarduduk
# pintu : pintu
# ditentukan : tentu
# admint : admint
# perjalanan : jalan
# memasak : masak
# najiba : najiba
# adila : adila
# syifaa : syifaa
# still : still
# modern : modern
# pengirimn : pengirimn
# program : program
# arti : arti
# unitsatu : unitsatu
# komplek : komplek
# dibilang : bilang
# hellow : hellow
# diperaturannya : atur
# malu : malu
# dukcapil : dukcapil
# dipersulit : sulit
# ubah : ubah
# seminggu : minggu
# hsil : hsil
# semuanya  : semua
# apalagiyg : apalagiyg
# promobuat : promobuat
# dijuallagimakin : dijuallagimakin
# cptpkok : cptpkok
# jos : jos
# okey : okey
# berbicara : bicara
# cepatsemua : cepatsemua
# segerrrrgak : segerrrrgak
# ke rumah : ke rumah
# peminatnya : minat
# ramahbarang : ramahbarang
# segri : segri
# kekirim : kirim
# karton : karton
# musim : musim
# buble : buble
# alumuniumfoiles : alumuniumfoiles
# batu : batu
# segarinya : segar
# fasilitasnya : fasilitas
# keterbatasan : batas
# adahabis : adahabis
# kendalanya : kendala
# balasan : balas
# lagipun : lagi
# numpuk : numpuk
# membsntu : membsntu
# dahsyat : dahsyat
# indonesia : indonesia
# premium : premium
# sale : sale
# repeat : repeat
# diam : diam
# dirmah : dirmah
# april : april
# mengganggu : ganggu
# buruburu : buruburu
# pulang : pulang
# sinisayuranbuahtlornya : sinisayuranbuahtlornya
# segarmantappp : segarmantappp
# segarisegala : segarisegala
# real : real
# nyacuma : nyacuma
# tempenya : tempe
# dibelah : belah
# hancur : hancur
# segerpengiriman : segerpengiriman
# rapibarangnya : rapibarangnya
# bahakan : bahak
# menguntungkan : untung
# sejenisnya : jenis
# ceritain : ceritain
# pikirpikir : pikirpikir
# repead : repead
# realpict : realpict
# terpecaya : terpecaya
# segarj : segarj
# penggiriman : penggiriman
# baikpengiriman : baikpengiriman
# mantaf : mantaf
# segarnya : segar
# bonusnya : bonus
# bayam : bayam
# okk : okk
# check : check
# bgsklau : bgsklau
# infokanjd : infokanjd
# segarimksh : segarimksh
# datng : datng
# dikala : kala
# bagussegarpengiriman : bagussegarpengiriman
# cepatkemasan : cepatkemasan
# barangy : barangy
# jugabarang : jugabarang
# pertamacukup : pertamacukup
# memuaskansayuran : memuaskansayuran
# trimakasih : trimakasih
# kredibilitas : kredibilitas
# lupa : lupa
# mantullll : mantullll
# variasinya : variasi
# bawaannya : bawa
# usul : usul
# olahan : olah
# mis : mis
# bumbu : bumbu
# laos : laos
# brngny : brngny
# ramahsangat : ramahsangat
# urusan : urus
# efesien : efesien
# bangeeettttt : bangeeettttt
# bingittsss : bingittsss
# murceee : murceee
# muncul : muncul
# excellent : excellent
# serasa : serasa
# kebun : kebun
# brang : brang
# realpick : realpick
# puassssss : puassssss
# bangetsayuran : bangetsayuran
# syeger : syeger
# woooww : woooww
# merk : merk
# gorengnya : goreng
# warnanya : warna
# keruh : keruh
# freezer : freezer
# lapisan : lapis
# es : es
# thaankss : thaankss
# tambah : tambah
# mayurnya : mayur
# bumbunya : bumbu
# kirimannya : kirim
# keluarga : keluarga
# kaki : kaki
# limakesegarannya : limakesegarannya
# bergaransigratis : bergaransigratis
# kirimkiriman : kirimkiriman
# kilattepat : kilattepat
# waktubanyak : waktubanyak
# hadiahnya : hadiah
# belnj : belnj
# okee : okee
# kerren : kerren
# cepatngk : cepatngk
# kawatir : kawatir
# sekalisayuran : sekalisayuran
# baguspkoknya : baguspkoknya
# puasmksh : puasmksh
# segat : segat
# paham : paham
# kode : kode
# heee : heee
# mudahmudahan : mudahmudahan
# ditmbh : ditmbh
# sngat : sngat
# memuaskanbarang : memuaskanbarang
# ramahbnyak : ramahbnyak
# segarpuas : segarpuas
# segarhemat : segarhemat
# bekerjapengiriman : bekerjapengiriman
# ramahkemasan : ramahkemasan
# syuran : syur
# puasnya : puas
# froze : froze
# ys : ys
# pengamalan : amal
# kondisinya : kondisi
# dipacking : dipacking
# aga : aga
# pucat : pucat
# fiam : fiam
# alhamdulillahsayuran : alhamdulillahsayuran
# segarkemasan : segarkemasan
# pesanandatang : pesanandatang
# minblanja : minblanja
# dpat : dpat
# migor : migor
# sugari : sugar
# pisangnya : pisang
# buaha : buaha
# dear : dear
# tumis : tumis
# pare : pare
# konsumsi : konsumsi
# jeruknya : jeruk
# berharap : harap
# depannya : depan
# ramh : ramh
# mantafff : mantafff
# bangeey : bangeey
# bugar : bugar
# sayurn : sayurn
# brsaing : brsaing
# kang : kang
# pstinya : pstinya
# disortir : sortir
# promodan : promodan
# lngkapi : lngkapi
# kiriman : kirim
# berbelanjaga : berbelanjaga
# antarbnyk : antarbnyk
# productny : productny
# merakyat : rakyat
# lengkaptapi : lengkaptapi
# terongnya : terong
# semuatks : semuatks
# kategori : kategori
# sub : sub
# pemilihan : pilih
# diberitahu : diberitahu
# kosongtidak : kosongtidak
# segartidak : segartidak
# standart : standart
# totalan : total
# kepengen : ken
# bawa perasaan : bawa asa
# disegariresponya : disegariresponya
# cepettrinaksih : cepettrinaksih
# linknyatrinaksih : linknyatrinaksih
# goodbarangnya : goodbarangnya
# vouchernya : vouchernya
# ngater : ngater
# orderanya : orderanya
# disinii : sini
# semuasangat : semuasangat
# shopping : shopping
# berbelnjapengemasan : berbelnjapengemasan
# rapibanyak : rapibanyak
# promoharganya : promoharganya
# murahterimakasih : murahterimakasih
# gegari : gegar
# kecamatan : camat
# rebu : rebu
# perbyk : perbyk
# variasi : variasi
# vouchery : vouchery
# berlu : berlu
# akurat : akurat
# lagidengan : lagidengan
# delete : delete
# nih : nih
# tanggapi : tanggap
# dibalas : balas
# penyok : penyok
# baiksayurannya : baiksayurannya
# freshpacking : freshpacking
# rapisering : rapisering
# mkasih : mkasih
# diskondan : diskondan
# khawatir : khawatir
# rendah : rendah
# sediakan : sedia
# utuh : utuh
# opsi : opsi
# terbungkus : bungkus
# minimalis : minimal
# user : user
# friendly : friendly
# ketepatan : tepat
# kangkung : kangkung
# kebuang : buang
# tangkai : tangkai
# daunnya : daun
# bayi : bayi
# iga : iga
# dibohongin : dibohongin
# bombay : bombay
# enggak apa-apa : enggak apa
# cepatpacking : cepatpacking
# menurun : turun
# hrgnya : hrgnya
# segarisukses : segarisukses
# perbnyak : perbnyak
# didiskonnya : diskon
# pertahan : tahan
# belanjag : belanjag
# desakn : desakn
# pasartinggal : pasartinggal
# belanjaanbsok : belanjaanbsok
# presharga : presharga
# disconnya : disconnya
# borong : borong
# tpt : tpt
# memuudahkan : memuudahkan
# bikin : bikin
# dbles : dbles
# mslah : mslah
# slesai : slesai
# help : help
# memuaskandpt : memuaskandpt
# zeezzz : zeezzz
# zz : zz
# sayuranbuah : sayuranbuah
# adaan : ada
# dress : dress
# sagari : sagar
# refereal : refereal
# awallnya : awallnya
# diubah : ubah
# eeeh : eeeh
# dimaasukin : dimaasukin
# hasil : hasil
# aplikasimya : aplikasimya
# dpet : dpet
# aaaaahh : aaaaahh
# disediakan : sedia
# kepala : kepala
# membutuhkan : butuh
# unt : unt
# street : street
# feeding : feeding
# kucing : kucing
# strays : strays
# exommers : exommers
# disiniayoo : disiniayoo
# disrgari : disrgari
# semuanyan : semuanyan
# thxyou : thxyou
# pelayanaanya : pelayanaanya
# mantapks : mantapks
# kosongtdk : kosongtdk
# direfundganti : direfundganti
# doanggg : doanggg
# nanem : nanem
# lamalama : lamalama
# komplittt : komplittt
# lah : lah
# lusa : lusa
# dipke : dipke
# perbagus : bagus
# promobonus : promobonus
# belanj : belanj
# amannn : amannn
# kembung : kembung
# matanya : mata
# hmpr : hmpr
# boro : boro
# ratingnya : ratingnya
# out : out
# sort : sort
# berdasarkan : dasar
# nemu : nemu
# menggenapkan : genap
# orderanmks : orderanmks
# kualiatas : kualiatas
# rapisyrn : rapisyrn
# cepatutk : cepatutk
# boros : boros
# kertasnya : kertas
# harganyaaaa : harganyaaaa
# kertas : kertas
# kadaluwarsaaa : kadaluwarsaaa
# siasiain : siasiain
# berusaha : usaha
# mengurangi : kurang
# pemakaian : pakai
# gratisnya : gratis
# mantaaaappp : mantaaaappp
# cepattepat : cepattepat
# patut : patut
# recomendasikan : recomendasikan
# dijaminkan : jamin
# kesegarannya : segar
# mengedepankan : depan
# temukan : temu
# rupiah : rupiah
# yra : yra
# trjamin : trjamin
# ckrg : ckrg
# kembali : kembali
# gratisan : gratis
# minyakny : minyakny
# dagingnyadagingnya : dagingnyadagingnya
# gelapdisitu : gelapdisitu
# freshtapi : freshtapi
# pelajaran : ajar
# nyabrg : nyabrg
# puuuuuaaaaasss : puuuuuaaaaasss
# mantappppengalaman : mantappppengalaman
# tambahkn : tambahkn
# puasorder : puasorder
# sampaimakasih : sampaimakasih
# tomat : tomat
# belah : belah
# berjamur : jamur
# pesananmsh : pesananmsh
# promopromo : promopromo
# bsgud : bsgud
# sekaliharga : sekaliharga
# bersaingngga : bersaingngga
# gratisanpengiriman : gratisanpengiriman
# segarisayuran : segarisayuran
# notif : notif
# cowok : cowok
# enakan : enak
# rban : rban
# bagusgk : bagusgk
# mengcewakan : mengcewakan
# tenkiyuu : tenkiyuu
# buatvpromonya : buatvpromonya
# masalah : masalah
# penjualan : jual
# bhan : bhan
# ketemu : ketemu
# soulmate : soulmate
# tharylestari : tharylestari
# thary : thary
# murahmurah : murahmurah
# repotrepot : repotrepot
# rapitinggal : rapitinggal
# mudahharga : mudahharga
# murahmudahcepatdan : murahmudahcepatdan
# untungnya : untung
# ...
# kwalitassmga : kwalitassmga
# mantapjadi : mantapjadi
# pasarpengiriman : pasarpengiriman
# waktupruduknya : waktupruduknya
# rekomendand : rekomendand
# rymah : rymah
# tngga : tngga
# ramahsukses : ramahsukses
# bangga : bangga
# memudah : mudah
# sehati : sehat
# freshhpengemasann : freshhpengemasann
# baik : baik
# bangettpengirimann : bangettpengirimann
# estimasiikurirr : estimasiikurirr
# miss : miss
# romo : romo
# cepathari : cepathari
# lhaaaskrgmalah : lhaaaskrgmalah
# jls : jls
# apka : apka
# upgrade : upgrade
# kuota : kuota
# dikerdus : dikerdus
# woooowww : woooowww
# kamisjumat : kamisjumat
# pencairan : cair
# segariidijaga : segariidijaga
# lutus : lutus
# head : head
# normal : normal
# putuskan : putus
# angkuh : angkuh
# paketannya : paket
# diperbnyak : diperbnyak
# doenk : doenk
# paketa : paketa
# opor : opor
# rawon : rawon
# semur : semur
# dlll : dlll
# dioseng : dioseng
# disyur : syur
# pkonyah : pkonyah
# apliksi : apliksi
# sendritmbah : sendritmbah
# segarny : segarny
# virtual : virtual
# acc : acc
# ditanggapi : tanggap
# haritp : haritp
# terlambar : lambar
# ptg : ptg
# dimasukan : masuk
# kekulkas : kulkas
# tahan : tahan
# ikanayamsayuran : ikanayamsayuran
# gorengyg : gorengyg
# hak : hak
# dikeranjang : keranjang
# habissama : habissama
# diambil : ambil
# segarijadi : segarijadi
# dikondisi : kondisi
# pandemimusim : pandemimusim
# ideide : ideide
# okm : okm
# gud : gud
# topfres : topfres
# segarisayur : segarisayur
# pesenansegar : pesenansegar
# segarharganya : segarharganya
# bolongbanyak : bolongbanyak
# caseback : caseback
# gopaythank : gopaythank
# segariditunggu : segariditunggu
# cetar : cetar
# minimun : minimun
# tertentusukses : tertentusukses
# thankyou : thankyou
# ampla : ampla
# bnyakin : bnyakin
# gratisannya : gratis
# grats : grats
# minyk : minyk
# recomendasiin : recomendasiin
# temn : temn
# mantuil : mantuil
# segerbngt : segerbngt
# bangetada : bangetada
# esnya : es
# same : same
# day : day
# ngejar : ngejar
# dtangnya : dtangnya
# referalpromo : referalpromo
# flayerchat : flayerchat
# gift : gift
# pembelajaan : baja
# flyer : flyer
# flayer : flayer
# rumahdpt : rumahdpt
# kamarin : kamarin
# smuagood : smuagood
# banding : banding
# buahsayur : buahsayur
# semuaditambah : semuaditambah
# freeong : freeong
# segariok : segariok
# praktisss : praktisss
# produksinya : produksi
# segarberkwalitas : segarberkwalitas
# dikrm : dikrm
# waktukurir : waktukurir
# smart : smart
# shoping : shoping
# topppp : topppp
# bekunya : beku
# rapiih : rapiih
# dsisni : dsisni
# marketingnya : marketingnya
# merdeka : merdeka
# bermitra : mitra
# perumahan : rumah
# applicationso : applicationso
# price : price
# semuathx : semuathx
# sanagt : sanagt
# puasacepet : puasacepet
# im : im
# ntu : ntu
# pula : pula
# nikmat : nikmat
# segaribahannya : segaribahannya
# menggantikannya : ganti
# dividiokan : dividiokan
# unboxingnya : unboxingnya
# prngantaran : prngantaran
# amandan : amandan
# freshkurir : freshkurir
# pengiman : kim
# segergak : segergak
# segaripelayanannya : segaripelayanannya
# memuaskankalo : memuaskankalo
# kosongpun : kosong
# produknyakualitas : produknyakualitas
# bagusn : bagusn
# waktumuantaaapppthanks : waktumuantaaapppthanks
# tradisionil : tradisionil
# segardagingan : segardagingan
# siisering : siisering
# yaasukses : yaasukses
# wrape : wrape
# freshpuas : freshpuas
# dikirimnya : kirim
# disegaridaging : disegaridaging
# sayuranbuahdll : sayuranbuahdll
# fresdan : fresdan
# voucerdan : voucerdan
# belanjacoba : belanjacoba
# disegarimantap : disegarimantap
# aslinya : asli
# pengwmasannya : pengwmasannya
# bismillah : bismillah
# at : at
# really : really
# long : long
# langganantx : langganantx
# recomendeddan : recomendeddan
# yesok : yesok
# marketkl : marketkl
# promonyamanthankyou : promonyamanthankyou
# mengecewakantrimakasih : mengecewakantrimakasih
# mahis : mah
# bestjadi : bestjadi
# kecanduan : candu
# dibuatnyajadi : dibuatnyajadi
# uyk : uyk
# allhamdulillah : allhamdulillah
# langgaanan : langgaanan
# luarbiasa : luarbiasa
# pot : pot
# jari : jari
# budget : budget
# situ : situ
# terjangkauyg : terjangkauyg
# pesananbeneran : pesananbeneran
# waktukami : waktukami
# tidakmengecewakankualitasnya : tidakmengecewakankualitasnya
# segeran : segeran
# sukaakk : sukaakk
# berdagang : dagang
# disinikemasannya : disinikemasannya
# rapihproduk : rapihproduk
# semuasuka : semuasuka
# dnga : dnga
# babyshops : babyshops
# barangnyapunbagus : barangnyapunbagus
# reaponnya : reaponnya
# kemasnya : kemas
# saftey : saftey
# sesuka : suka
# kerjasamanya : kerjasamanya
# kesegaranny : kesegaranny
# bangetaq : bangetaq
# sukaaq : sukaaq
# dalamperjalanan : dalamperjalanan
# sebelumkirim : sebelumkirim
# menggiurkan : giur
# lengkapi : lengkap
# buhan : buhan
# okeyyy : okeyyy
# sayursn : sayursn
# pesananharga : pesananharga
# busuksemua : busuksemua
# lgpuas : lgpuas
# okepackingnya : okepackingnya
# segaripengiriman : segaripengiriman
# anterpun : anter
# vc : vc
# murahpokoknya : murahpokoknya
# cepetrespon : cepetrespon
# semngatt : semngatt
# lambattttttttttttt : lambattttttttttttt
# fat : fat
# hematmurahpraktis : hematmurahpraktis
# perbatasan : batas
# cisaukrumpin : cisaukrumpin
# bsd : bsd
# segarisemenjak : segarisemenjak
# kenalkamu : kenalkamu
# max : max
# pesananyasegar : pesananyasegar
# segaritrm : segaritrm
# plihin : plihin
# castemer : castemer
# products : products
# cepatharga : cepatharga
# terjangkautapi : terjangkautapi
# anggur : anggur
# rusaknext : rusaknext
# produky : produky
# menjadi : jadi
# berkat : berkat
# bless : bless
# excelentdgn : excelentdgn
# schedule : schedule
# seharicari : seharicari
# hadiahbuah : hadiahbuah
# menjamin : jamin
# pandemic : pandemic
# semuanyaterimakasih : semuanyaterimakasih
# segaripasti : segaripasti
# qualtynya : qualtynya
# rumahnya : rumah
# persabunan : sabun
# kmarentapi : kmarentapi
# mantapz : mantapz
# bangetzz : bangetzz
# sadarnya : sadar
# rebus : rebus
# kelihatan : lihat
# bagusbelanja : bagusbelanja
# praktisbelum : praktisbelum
# menarikmakasi : menarikmakasi
# okjd : okjd
# besty : besty
# aayuran : aayuran
# oncom : oncom
# muantap : muantap
# memuaskanbanyak : memuaskanbanyak
# mantapdan : mantapdan
# oline : oline
# jazaakumullahu : jazaakumullahu
# khairan : khair
# penggantian : ganti
# beripa : beripa
# antarnya : antar
# bingitzbesok : bingitzbesok
# sekaliad : sekaliad
# belinyasekarang : belinyasekarang
# lagitinggal : lagitinggal
# inibesok : inibesok
# membaca : baca
# pengisian : isi
# dst : dst
# keesokan : esok
# diiformasikan : diiformasikan
# periksa : periksa
# kotak : kotak
# pemesan : mes
# ukiran : ukir
# bagusx : bagusx
# mantuuulll : mantuuulll
# safty : safty
# kerenelegan : kerenelegan
# bagusproduk : bagusproduk
# diantarkan : antar
# datangdatang : datangdatang
# bekerjatak : bekerjatak
# rumahsudah : rumahsudah
# agen : agen
# centre : centre
# tinggalkan : tinggal
# kamibrg : kamibrg
# dibayari : bayar
# agennya : agen
# agennyakomunikasi : agennyakomunikasi
# wlopun : wlopun
# membludaknya : membludaknya
# corona : corona
# imbas : imbas
# ssh : ssh
# komplennya : komplennya
# buahnyagood : buahnyagood
# bersyukur : syukur
# disiniharga : disiniharga
# bersahabatlebih : bersahabatlebih
# apik : apik
# bagusjaminan : bagusjaminan
# wawww : wawww
# sanah : sanah
# disinisemoga : disinisemoga
# frest : frest
# mas : mas
# frash : frash
# suks : suks
# semuapacking : semuapacking
# tertutup : tutup
# rapirecommended : rapirecommended
# syekalee : syekalee
# buaguuuuuusss : buaguuuuuusss
# apalagi : apalagi
# kebersihan : bersih
# mgg : mgg
# mantaaabs : mantaaabs
# blnjaan : blnjaan
# banyakpengiriman : banyakpengiriman
# cepatsayuranbuahikandan : cepatsayuranbuahikandan
# berkomitmen : komitmen
# senilai : nila
# drmh : drmh
# brgnyabyk : brgnyabyk
# murahudah : murahudah
# pademi : pademi
# mantapsssdapat : mantapsssdapat
# trusssfresss : trusssfresss
# hhmmm : hhmmm
# segarikualitas : segarikualitas
# sayurannyaharga : sayurannyaharga
# dori : dor
# kesukaan : suka
# pertama : pertama
# feedback : feedback
# karen : karen
# mantabzrutin : mantabzrutin
# blnjanya : blnjanya
# psn : psn
# kirimnya : kirim
# berkualitasmutu : berkualitasmutu
# freshtunggu : freshtunggu
# apalagimari : apalagimari
# segariidelizabethmart : segariidelizabethmart
# segarifree : segarifree
# jugaada : jugaada
# nyamksih : nyamksih
# larang : larang
# pasaralhamdulillah : pasaralhamdulillah
# dapurku : dapur
# anterinbarangnya : anterinbarangnya
# bersihmakin : bersihmakin
# dongtolongggggggg : dongtolongggggggg
# kolom : kolom
# diisilihat : diisilihat
# sekeluarga : keluarga
# segarthanks : segarthanks
# digunakandan : digunakandan
# email : email
# by : by
# banknya : bank
# pembaruan : baru
# materibramah : materibramah
# menyampah : sampah
# adapanduan : adapanduan
# yaathanks : yaathanks
# melorot : lorot
# cepatbrang : cepatbrang
# segarijangan : segarijangan
# tampa : tampa
# puassayuran : puassayuran
# gampng : gampng
# isoman : isoman
# topp : topp
# menyajikan : saji
# alhamdulillahselama : alhamdulillahselama
# melanda : landa
# menjadikan : jadi
# perbelanjaan : belanja
# pandemik : pandemik
# isolasi : isolasi
# buahbuahnya : buahbuahnya
# berjaya : jaya
# menarikterbaiknice : menarikterbaiknice
# mainmain : mainmain
# dry : dry
# dolar : dolar
# pemesanannya : mesan
# protokol : protokol
# kesehatan : sehat
# sagat : sagat
# disetiap : tiap
# okeyy : okeyy
# warga : warga
# slogan : slogan
# macetmacetan : macetmacetan
# kelasnya : kelas
# terbagus : bagus
# coviddapat : coviddapat
# rumahbuahsayur : rumahbuahsayur
# kerumahdengan : kerumahdengan
# ab : ab
# mantaps : mantaps
# moto : moto
# aplilakasi : aplilakasi
# sebanyaknya : banyak
# promosinya : promosi
# jelasrespon : jelasrespon
# lambanini : lambanini
# terdebet : debet
# disertai : serta
# respect : respect
# we : we
# mpe : mpe
# ijo : ijo
# dagh : dagh
# hangus : hangus
# cancelnya : cancelnya
# ampun : ampun
# tombol : tombol
# aplikasihrs : aplikasihrs
# dibalessebelll : dibalessebelll
# chatnyajd : chatnyajd
# ssyrannja : ssyrannja
# pegertian : pegertian
# karan : karan
# shopee : shopee
# mausk : mausk
# seputar : putar
# pengambilan : ambil
# sameday : sameday
# segarfresh : segarfresh
# dijangkau : jangkau
# dihari : hari
# batam : batam
# riview : riview
# bestmantul : bestmantul
# bngit : bngit
# jaminan : jamin
# aplikasinyajng : aplikasinyajng
# tergoda : goda
# copot : copot
# uhuyy : uhuyy
# mendingan : mending
# inibelanja : inibelanja
# mudahbarangbarangnya : mudahbarangbarangnya
# freshpromonya : freshpromonya
# suangatt : suangatt
# pelyanan : pelyanan
# mantapss : mantapss
# mantapzzz : mantapzzz
# beersih : beersih
# biasalah : biasa
# kirimkan : kirim
# rumahsukses : rumahsukses
# lgsemoga : lgsemoga
# milenial : milenial
# ngecewain : ngecewain
# youuu : youuu
# cp : cp
# promotor : promotor
# bagusm : bagusm
# mbaknya : mbak
# spg : spg
# eli : eli
# baikbgt : baikbgt
# elitha : elitha
# playanan : playanan
# okeee : okeee
# baguslebih : baguslebih
# berkebutuhan : butuh
# websitenya : websitenya
# mya : mya
# mantol : mantol
# betol : betol
# murahbanyakpromonya : murahbanyakpromonya
# luar : luar
# aplikasinyatambah : aplikasinyatambah
# belanjapelayanan : belanjapelayanan
# partner : partner
# cihuy : cihuy
# gaess : gaess
# kuatir : kuatir
# diklaim : klaim
# semiga : semiga
# apliaksi : apliaksi
# barunya : baru
# mudahnya : mudah
# onkir : onkir
# terbaiksekaligus : terbaiksekaligus
# benermembantu : benermembantu
# okehh : okehh
# from : from
# oven : oven
# cavendish : cavendish
# sarapanku : sarap
# tawarkan : tawar
# dipilih : pilih
# kebesokan : besok
# vegetables : vegetables
# fruit : fruit
# meat : meat
# groceries : groceries
# only : only
# which : which
# complete : complete
# continues : continues
# pruduknya : pruduknya
# ude : ude
# heginis : heginis
# dupermarket : dupermarket
# onlien : onlien
# higinis : higinis
# paginyaaa : paginyaaa
# disv : disv
# diinput : diinput
# lagibarang : lagibarang
# waktudan : waktudan
# kejutan : kejut
# dipetik : petik
# pohonya : pohonya
# sulaiman : sulaiman
# onlen : onlen
# mengutamakan : utama
# unik : unik
# kesibukan : sibuk
# {'mantap': 'mantap', 'semenjak': 'semenjak', 'cod': 'cod', 'ditiadakan': 'tiada', 'wilayahku': 'wilayah', 'sudah': 'sudah', 'pakai': 'pakai', 'akupindah': 'akupindah', 'sebelahlbh': 'sebelahlbh', 'murah': 'murah', 'sayang': 'sayang', 'banget': 'banget', 'lengkap': 'lengkap', 'sekalian': 'sekali', 'kan': 'kan', 'beli': 'beli', 'belanja': 'belanja', 'lihat': 'lihat', 'teman': 'teman', 'lewat': 'lewat', 'aplikasii': 'aplikasi', 'pengin': 'pengin', 'coba': 'coba', 'sayuran': 'sayur', 'freshbersih': 'freshbersih', 'barang': 'barang', 'kualitas': 'kualitas', 'fresh': 'fresh', 'segar': 'segar', 'bersih': 'bersih', 'pengiriman': 'kirim', 'aman': 'aman', 'cepat': 'cepat', 'bkalan': 'bkalan', 'langganan': 'langgan', 'deh': 'deh', 'harganya': 'harga', 'tinggal': 'tinggal', 'tunggu': 'tunggu', 'enggak': 'enggak', 'rumah': 'rumah', 'sekarang': 'sekarang', 'yang': 'yang', 'komplain': 'komplain', 'mengaco': 'aco', 'transfer': 'transfer', 'nugelo': 'nugelo', 'segari': 'segar', 'produk': 'produk', 'bagus': 'bagus', 'packaging': 'packaging', 'safe': 'safe', 'cepatbarang': 'cepatbarang', 'praktis': 'praktis', 'beberapa': 'beberapa', 'kali': 'kali', 'kosong': 'kosong', 'display': 'display', 'lahbaik': 'lahbaik', 'promo': 'promo', 'ada': 'ada', 'uang': 'uang', 'coin': 'coin', 'begitu': 'begitu', 'biaya': 'biaya', 'penanganan': 'tangan', 'gabung': 'gabung', 'mending': 'mending', 'pindah': 'pindah', 'toko': 'toko', 'sebelah': 'belah', 'keren': 'keren', 'membantu': 'bantu', 'emak': 'emak', 'dari': 'dari', 'tukang': 'tukang', 'sayur': 'sayur', 'tempatku': 'tempat', 'min': 'min', 'sampai': 'sampai', 'sayurnya': 'sayur', 'promonya': 'promonya', 'very': 'very', 'worth': 'worth', 'itu': 'itu', 'anak': 'anak', 'riweh': 'riweh', 'pesan': 'pesan', 'hp': 'hp', 'langsung': 'langsung', 'buah': 'buah', 'buahan': 'buah', 'juga': 'juga', 'harga': 'harga', 'ok': 'ok', 'sesuai': 'sesuai', 'jadwal': 'jadwal', 'pengemasan': 'emas', 'telur': 'telur', 'ditingkatkan': 'tingkat', 'pengamanan': 'aman', 'ditindih': 'tindih', 'good': 'good', 'aplication': 'aplication', 'kebanyakan': 'banyak', 'refund': 'refund', 'saran': 'saran', 'mengadakan': 'ada', 'kuantitas': 'kuantitas', 'tutup': 'tutup', 'layanan': 'layan', 'jam': 'jam', 'telat': 'telat', 'menit': 'menit', 'okelah': 'oke', 'kurir': 'kurir', 'dihubungi': 'hubung', 'angkat': 'angkat', 'hubungi': 'hubung', 'cs': 'cs', 'maaf': 'maaf', 'tanggung': 'tanggung', 'kompensasi': 'kompensasi', 'apalah': 'apa', 'aplikasi': 'aplikasi', 'sayangnya': 'sayang', 'pemesanan': 'mesan', 'enggak bisa': 'enggak bisa', 'bayar': 'bayar', 'golden': 'golden', 'mom': 'mom', 'sehari': 'hari', 'bngetpelayanan': 'bngetpelayanan', 'pengantar': 'antar', 'mantul': 'mantul', 'utama': 'utama', 'dapat': 'dapat', 'besaran': 'besar', 'disegari': 'gari', 'respon': 'respon', 'pelayanan': 'layan', 'lama': 'lama', 'bagusloading': 'bagusloading', 'lamamungkin': 'lamamungkin', 'server': 'server', 'the': 'the', 'worst': 'worst', 'pengalaman': 'alam', 'daging': 'daging', 'giling': 'giling', 'packing': 'packing', 'rapi': 'rapi', 'dus': 'dus', 'tapi': 'tapi', 'beku': 'beku', 'terima': 'terima', 'kasih': 'kasih', 'puas': 'puas', 'menarik': 'tarik', 'rekomendasi': 'rekomendasi', 'kosan': 'kosan', 'pasar': 'pasar', 'pedagang': 'dagang', 'bahan': 'bahan', 'bahannya': 'bahan', 'sukakk': 'sukakk', 'semoga': 'moga', 'bisa': 'bisa', 'miring': 'miring', 'maklum': 'maklum', 'mak': 'mak', 'zaman': 'zaman', 'wajib': 'wajib', 'efisiensi': 'efisiensi', 'kebutuhan': 'butuh', 'masak': 'masak', 'mudah': 'mudah', 'buahnya': 'buah', 'mengirim': 'kirim', 'mageran': 'mageran', 'alhamdulillah': 'alhamdulillah', 'repot': 'repot', 'kepasar': 'pasar', 'terjangkau': 'jangkau', 'kemarin': 'kemarin', 'diskon': 'diskon', 'free': 'free', 'ongkir': 'ongkir', 'sukses': 'sukses', 'suka': 'suka', 'pengirimannya': 'kirim', 'ramah': 'ramah', 'customer': 'customer', 'bantuan': 'bantu', 'care': 'care', 'melayani': 'layan', 'kak': 'kak', 'jangkauan': 'jangkau', 'terbatas': 'batas', 'bersaing': 'saing', 'a ...
# ------------------------
# Pandas Apply:   0%|          | 0/5206 [00:00<?, ?it/s]
# 0                                                [mantap]
# 1       [semenjak, cod, tiada, wilayah, sudah, pakai, ...
# 2       [sayang, banget, lengkap, lengkap, sekali, kan...
# 3       [belanja, lihat, teman, belanja, lewat, aplika...
# 4                  [sayur, freshbersih, barang, kualitas]
#                               ...
# 5201                        [barang, fresh, kirim, cepat]
# 5202                                               [baik]
# 5203                                  [seller, bagaimana]
# 5204    [aplikasi, bantu, sibuk, rumah, pandemi, langs...
# 5205    [suruh, masuk, kode, pin, error, nomor, telpon...
# Name: content_tokens_stemmed, Length: 5206, dtype: object

# %%
data.to_csv("/content/drive/MyDrive/3Text_Preprocessing_daritsv.tsv", sep='\t', index=False)

# %%
data.to_csv("Text_Preprocessing_daritsv.tsv", sep='\t', index=False)

# %%
data.to_csv("3Text_Preprocessing_daritsv.csv")
