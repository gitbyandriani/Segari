# %%
import pandas as pd

# %%
data = pd.read_csv ("/content/drive/MyDrive/𝓼𝓴𝓻𝓲𝓹𝓼𝓲 /dataset/segari_data_not_clean.csv")

# %%
data.head(15)
# Out:
#     score                                            content  category
# 0       5                                         Mantabbbbb  positive
# 1       2  Semenjak cod ditiadakan yg ke wilayahku udah g...  negative
# 2       5  Sayang bgt ya buat si kecil kurang lengkap klo...  positive
# 3       5  Belum pernah belanja, tapi liatt teman selalu ...  positive
# 4       5  sayuran fresh,bersih & semua barang kualitas baik  positive
# 5       5  kualitas barang nya fresh seger bersih2 dan pe...  positive
# 6       1  Skrg tiap belanja ada aja yag di komplain , ta...  negative
# 7       5  produk nya baguss loh, packaging nya juga safe...  positive
# 8       5                      pengiriman cepat,barang bagus  positive
# 9       5                                bagus cepat praktis  positive
# 10      2  Bbrp kali belanja disini, banyak barang yg kos...  negative
# 11      5  keren sangat membantu emak2 yg jauh dr tukang ...  positive
# ...

# %%
import re

# %%
data = pd.read_csv("/content/drive/MyDrive/𝓼𝓴𝓻𝓲𝓹𝓼𝓲 /dataset/segari_data_not_clean.csv")

# %%
import csv
import re

def clean_text(text):
    # Hapus URL
    text = re.sub(r'http\S+', '', text)

    # Hapus karakter khusus, tanda baca, dan simbol lainnya
    text = re.sub(r'[^\w\s]', '', text)

    # Hapus emotikon
    text = re.sub(r'[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F700-\U0001F77F\U0001F780-\U0001F7FF\U0001F800-\U0001F8FF\U0001F900-\U0001F9FF\U0001FA00-\U0001FA6F\U0001FA70-\U0001FAFF\U00002702-\U000027B0\U000024C2-\U0001F251]+', '', text)

    # Hapus karakter berulang, misalnya "hellooooo"
    text = re.sub(r'(.)\1{2,}', r'\1', text)

    # Mengubah teks menjadi lowercase
    text = text.lower()

    return text

input_filename = '/content/drive/MyDrive/𝓼𝓴𝓻𝓲𝓹𝓼𝓲 /dataset/segari_data_not_clean.csv'   # Nama file CSV input
output_filename = 'segari_dataset_file_bersih2.csv.csv' # Nama file CSV output

# Membaca file input dan menyimpan data dalam list
data = []
with open(input_filename, 'r', encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        if len(row) > 0:
            data.append(row)

# Membersihkan teks pada setiap baris data
for row in data:
    if len(row) > 1:
        row[1] = clean_text(row[1])  # Menganggap kolom teks berada di indeks 1, sesuaikan jika berbeda

# Menyimpan data yang sudah dibersihkan ke dalam file output
with open(output_filename, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    for row in data:
        writer.writerow(row)

# %%
# def clean_text(text):
#     # Hapus URL
#     text = re.sub(r'http\S+', '', text)

#     # Hapus karakter khusus, tanda baca, dan simbol lainnya
#     text = re.sub(r'[^\w\s]', '', text)

#     # Hapus emotikon
#     text = re.sub(r'[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F700-\U0001F77F\U0001F780-\U0001F7FF\U0001F800-\U0001F8FF\U0001F900-\U0001F9FF\U0001FA00-\U0001FA6F\U0001FA70-\U0001FAFF\U00002702-\U000027B0\U000024C2-\U0001F251]+', '', text)

#     # Hapus karakter berulang, misalnya "hellooooo"
#     text = re.sub(r'(.)\1{2,}', r'\1', text)

#     # Mengubah teks menjadi lowercase
#     text = text.lower()

#     return text

# %%
# # Membersihkan kolom teks dalam dataset
# data['text'] = data['text'].apply(clean_text)

# # Menyimpan dataset yang sudah dibersihkan ke file CSV baru
# data.to_csv('segari_dataset_file_bersih.csv', index=False)

# %%
# import pandas as pd
# import re

# def clean_text(text):
#     # Hapus URL
#     text = re.sub(r'http\S+', '', text)

#     # Hapus karakter khusus, tanda baca, dan simbol lainnya
#     text = re.sub(r'[^\w\s]', '', text)

#     # Hapus emotikon
#     text = re.sub(r'[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F700-\U0001F77F\U0001F780-\U0001F7FF\U0001F800-\U0001F8FF\U0001F900-\U0001F9FF\U0001FA00-\U0001FA6F\U0001FA70-\U0001FAFF\U00002702-\U000027B0\U000024C2-\U0001F251]+', '', text)

#     # Hapus karakter berulang, misalnya "hellooooo"
#     text = re.sub(r'(.)\1{2,}', r'\1', text)

#     # Mengubah teks menjadi lowercase
#     text = text.lower()

#     return text

# # Membaca dataset dari file CSV
# input_csv = '/content/drive/MyDrive/𝓼𝓴𝓻𝓲𝓹𝓼𝓲 /dataset/segari_data_not_clean.csv'
# output_csv = '/content/drive/MyDrive/𝓼𝓴𝓻𝓲𝓹𝓼𝓲 /dataset/segari_data_not_clean.csv'

# # Membaca dataset dari file CSV
# dataset = pd.read_csv(input_csv)

# # Membersihkan kolom teks dalam dataset
# data['text'] = data['text'].apply(clean_text)

# # Menyimpan dataset yang sudah dibersihkan ke file CSV baru
# data.to_csv(output_csv, index=False)

# print("Teks dalam dataset berhasil dibersihkan dan disimpan dalam", output_csv)
